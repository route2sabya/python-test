# %%
# Load Modules
from datetime import date
from nsepy import get_history

# %%
# collect required data using nsepy

# infosys
infy = get_history(symbol='INFY',
                   start=date(2015,1,1),
                   end=date(2015,12,31))

# tcs
tcs = get_history(symbol='TCS',
                   start=date(2015,1,1),
                   end=date(2015,12,31))

# nifty it Index
nifty_it = get_history(symbol="NIFTY IT",
                            start=date(2015,1,1),
                            end=date(2015,12,31),
                            index=True)

# %%
# Part - 1
#   Task 1

# %%
# function for creating list of windows
def rolling_windowSize(week_factor):

    window_size_list = []
    for i in range(0,52):
        window_size = (i+1) * week_factor
        if window_size < 53:
            window_size_list.append(window_size)
    return (window_size_list)

# %%
# function for calculation moving average
def calc_moving_avg(close_fieldname,window_list,df):
    closing = close_fieldname
    for i in window_list:
        ma_closing = 'moving_avg_{0}_{1}'.format(close_fieldname,i)
        df[ma_closing] = df[closing].rolling(window=i).mean()
        #infy[ma_closing] = infy[closing].rolling(window=30).mean()
        #nifty_it[ma_closing] = nifty_it[closing].rolling(window=30).mean()

    print (df.columns)
    return df

# %%
# create required moving average dataset for 'Close'
week_list = rolling_windowSize(4)
df_niftyIt = calc_moving_avg('Close',week_list,nifty_it)
df_infy = calc_moving_avg('Close',week_list,infy)
df_tcs = calc_moving_avg('Close',week_list,tcs)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Turnover',
#        'moving_avg_Close_4', 'moving_avg_Close_8', 'moving_avg_Close_12',
#        'moving_avg_Close_16', 'moving_avg_Close_20', 'moving_avg_Close_24',
#        'moving_avg_Close_28', 'moving_avg_Close_32', 'moving_avg_Close_36',
#        'moving_avg_Close_40', 'moving_avg_Close_44', 'moving_avg_Close_48',
#        'moving_avg_Close_52'],
#       dtype='object')
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'moving_avg_Close_4', 'moving_avg_Close_8',
#        'moving_avg_Close_12', 'moving_avg_Close_16', 'moving_avg_Close_20',
#        'moving_avg_Close_24', 'moving_avg_Close_28', 'moving_avg_Close_32',
#        'moving_avg_Close_36', 'moving_avg_Close_40', 'moving_avg_Close_44',
#        'moving_avg_Close_48', 'moving_avg_Close_52'],
#       dtype='object')
# ...

# %%
# Task 2
# rolling window

# %%
# generate 10 day, 20 day , 30 day, 40 day, 50 day, 60 day, 75 day moving average
new_week_list = [10,20,30,40,50,60,75]
df_ma_tcs = calc_moving_avg('Close',new_week_list,df_tcs)
df_ma_infy = calc_moving_avg('Close',new_week_list,df_infy)
df_ma_niftyIt = calc_moving_avg('Close',new_week_list,df_niftyIt)

# check how the data looks
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'moving_avg_Close_4', 'moving_avg_Close_8',
#        'moving_avg_Close_12', 'moving_avg_Close_16', 'moving_avg_Close_20',
#        'moving_avg_Close_24', 'moving_avg_Close_28', 'moving_avg_Close_32',
#        'moving_avg_Close_36', 'moving_avg_Close_40', 'moving_avg_Close_44',
#        'moving_avg_Close_48', 'moving_avg_Close_52', 'moving_avg_Close_10',
#        'moving_avg_Close_30', 'moving_avg_Close_50', 'moving_avg_Close_60',
#        'moving_avg_Close_75'],
#       dtype='object')
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'moving_avg_Close_4', 'moving_avg_Close_8',
#        'moving_avg_Close_12', 'moving_avg_Close_16', 'moving_avg_Close_20',
# ...

# %%
# Task 2
# Calculate shocks and direction of shock

# %%
# function to calculate change, shock(dummy), direction(dummy)
def calc_deriv(fieldname,df,threshold):

    shock = 'Shock'
    change = 'Change'
    direction = 'Direction'

    field_shock = '{0}_{1}'.format(fieldname,shock)
    field_change = '{0}_{1}'.format(fieldname,change)
    field_direction = '{0}_{1}'.format(fieldname,direction)
    df[field_shock] = 0
    df[field_change] = 0
    df[field_direction] = 0
    df[field_shock][0] = df[fieldname][0]
    df[field_shock] = ((df[fieldname]/df[fieldname].shift(1))*100) - 100
    df[field_change] = ((df[fieldname]/df[fieldname].shift(1))*100) - 100
    for i in range(1, len(df)):
        if (df[field_shock][i] > threshold) or (df[field_shock][i] < -(threshold)) :
            df[field_shock][i] = 1
                        
        else:
            df[field_shock][i] = 0

    for i in range(1, len(df)):
        if df[field_change][i] > 0:
            df[field_direction] [i] = 1
        else:
            df[field_direction] [i] = 0
    return df

# %%
# run function and get desired values 
# sub task 1
infy_vol_deriv = calc_deriv('Volume',infy,10)
tcs_vol_deriv = calc_deriv('Volume',tcs,10)
niftyIt_vol_deriv = calc_deriv('Volume',nifty_it,10)

# sub task 2
infy_close_deriv = calc_deriv('Close',infy_vol_deriv,2)
tcs_close_deriv = calc_deriv('Close',tcs_vol_deriv,2)
niftyIt_close_deriv = calc_deriv('Close',niftyIt_vol_deriv,2)

# sub task 3
#infy_Prevclose_deriv = calc_deriv('Prev Close',infy_close_deriv,2)
# Out:
# C:\Users\WELCOME\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\WELCOME\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\WELCOME\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
# Part 2

# %%
# import bokeh modules
import warnings
warnings.filterwarnings('ignore')
from bokeh.plotting import figure, show, output_file, output_notebook
from bokeh.palettes import Spectral11, colorblind, Inferno, BuGn, brewer
from bokeh.models import HoverTool, value, LabelSet, Legend, ColumnDataSource,LinearColorMapper,BasicTicker, PrintfTickFormatter, ColorBar
import datetime
import pandas as pd

from bokeh.palettes import Spectral3

# %%
# sub task 1 & 2
# build plot
infy['datetime'] = infy.index
infy['month'] = pd.DatetimeIndex(infy['datetime']).month

TOOLS = 'save,pan,box_zoom,reset,wheel_zoom,hover'
p = figure(title="Daily closing", y_axis_type="linear", plot_height = 400,
           tools = TOOLS, plot_width = 800)
p.xaxis.axis_label = 'month'
p.yaxis.axis_label = 'Closing value'
#p.circle(2010, infy.Close.min(), size = 10, color = 'red')

p.line(infy.month, infy.Close,line_color="blue", line_width = 2)
p.select_one(HoverTool).tooltips = [
    ('month', '@x'),
    ('Closing value', '@y'),
]
output_notebook() 
output_file("line_chart.html", title="Line Chart")
show(p)

# %%
TOOLS_mp = 'crosshair,save,pan,box_zoom,reset,wheel_zoom'
mp = figure(title="Category-wise stock measures through Time", y_axis_type="linear",x_axis_type='datetime', tools = TOOLS_mp)
infy_vol_deriv['datetime'] = infy_vol_deriv.index
tcs_vol_deriv['datetime'] = tcs_vol_deriv.index
niftyIt_vol_deriv['datetime'] = niftyIt_vol_deriv.index

infy_close_deriv['month'] = pd.DatetimeIndex(infy_vol_deriv['datetime']).month
tcs_close_deriv['month'] = pd.DatetimeIndex(tcs_vol_deriv['datetime']).month
niftyIt_close_deriv['month'] = pd.DatetimeIndex(niftyIt_vol_deriv['datetime']).month

mp.line(infy_close_deriv['month'], infy_close_deriv.Volume_Shock, legend="Volume Shock Dummy INFY", line_color="purple", line_width = 3)
mp.line(tcs_close_deriv['month'], tcs_close_deriv.Volume_Shock, legend="Volume Shock Dummy TCS", line_color="blue", line_width = 3)
mp.line(niftyIt_close_deriv['month'], niftyIt_close_deriv.Volume_Shock, legend="Volume Shock Dummy NIFTY IT", line_color="red", line_width = 3)
#mp.line(vehicle_theft['Date'], vehicle_theft.IncidntNum, legend="vehicle_theft", line_color = 'coral', line_width = 3)

#mp.line(larceny['Date'], larceny.IncidntNum, legend="larceny", line_color='green', line_width = 3)

#mp.line(vandalism['Date'], vandalism.IncidntNum, legend="vandalism", line_color="gold", line_width = 3)

#mp.line(arson['Date'], arson.IncidntNum, legend="arson", line_color="magenta",line_width = 3)

mp.legend.location = "top_left"

mp.xaxis.axis_label = 'Month'
mp.yaxis.axis_label = 'Values'


output_file("multiline_plot.html", title="Multi Line Plot")

show(mp)

# %%
# sub task 3 : Color timeseries between two volume shocks in a different color (Red)

infy_vol_deriv['datetime'] = infy_vol_deriv.index
infy_vol_deriv['month'] = pd.DatetimeIndex(infy_vol_deriv['datetime']).month

tcs_vol_deriv['datetime'] = tcs_vol_deriv.index
tcs_vol_deriv['month'] = pd.DatetimeIndex(tcs_vol_deriv['datetime']).month

niftyIt_vol_deriv['datetime'] = niftyIt_vol_deriv.index
niftyIt_vol_deriv['month'] = pd.DatetimeIndex(niftyIt_vol_deriv['datetime']).month

# %%
# bokeh area plot


from bokeh.plotting import figure, show, output_file
from bokeh.palettes import brewer

import numpy as np
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, LinearColorMapper
import holoviews as hv
hv.extension('bokeh') # using bokeh :)

df_infy.columns
df_infy['month'] = pd.DatetimeIndex(df_infy['datetime']).month

df_tcs.columns
df_tcs['month'] = pd.DatetimeIndex(df_tcs['datetime']).month

df_niftyIt.columns
df_niftyIt['month'] = pd.DatetimeIndex(df_niftyIt['datetime']).month

# %%
dims = dict(kdims='month', vdims='Volume_Shock')
infy_hv = hv.Area(df_infy, label='INFY', **dims)
tcs_hv   = hv.Area(df_tcs,   label='TCS',   **dims)
nifty_it_hv = hv.Area(df_niftyIt, label='NIFTY IT', **dims)
overlay = (infy_hv * tcs_hv * nifty_it_hv).options('Area', fill_alpha=0.5)
hv.ipython.display(overlay.relabel("Area Chart") + hv.Area.stack(overlay).relabel("Stacked Area Chart"))

# %%
TOOLS_mp = 'crosshair,save,pan,box_zoom,reset,wheel_zoom'
lp = figure(title="Category-wise stock measures through Time", y_axis_type="linear",x_axis_type='datetime', tools = TOOLS_mp)

lp.line(infy_vol_deriv['month'], infy_vol_deriv.Volume_Shock, legend="Volume Shock Dummy INFY", line_color="purple", line_width = 3)
lp.circle(tcs_vol_deriv['month'], tcs_vol_deriv.Volume_Shock, legend="y=10^x", fill_color="red", line_color="red", size=6)
show(lp)
output_notebook()
# Out:
#   <div class="bk-root" id="2a3ac484-a2f5-4ae1-810e-9aaf1c714397"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1918">Loading BokehJS ...</span>
#     </div>

# %%
# sub-task 4 : Pricing shock without volume shock - based on points a & b - Make a 0/1 dummy time series

# infy_vol_deriv
# tcs_vol_deriv
# niftyIt_vol_deriv
print (infy_vol_deriv.columns)
#for i in (len(infy_vol_deriv)):
print (infy_vol_deriv['Volume_Shock'])
print (infy_vol_deriv['Close_Shock'])
infy_vol_deriv['vol_shock_wo_close_shock'] = 0
for i in range(1,len(infy_vol_deriv)):
    shock_vol = infy_vol_deriv['Volume_Shock'][i]
    shock_close = infy_vol_deriv['Close_Shock'][i]
    if (shock_vol == 1) & (shock_close == 0):
          infy_vol_deriv['vol_shock_wo_close_shock'][i] = 0
    else:
          infy_vol_deriv['vol_shock_wo_close_shock'][i] = 0
print (infy_vol_deriv['vol_shock_wo_close_shock']) # desired column
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble', 'moving_avg_Close_4', 'moving_avg_Close_8',
#        'moving_avg_Close_12', 'moving_avg_Close_16', 'moving_avg_Close_20',
#        'moving_avg_Close_24', 'moving_avg_Close_28', 'moving_avg_Close_32',
#        'moving_avg_Close_36', 'moving_avg_Close_40', 'moving_avg_Close_44',
#        'moving_avg_Close_48', 'moving_avg_Close_52', 'moving_avg_Close_10',
#        'moving_avg_Close_30', 'moving_avg_Close_50', 'moving_avg_Close_60',
#        'moving_avg_Close_75', 'Volume_Shock', 'Volume_Change',
#        'Volume_Direction', 'Close_Shock', 'Close_Change', 'Close_Direction',
#        'datetime', 'month'],
#       dtype='object')
# Date
# 2015-01-01    NaN
# 2015-01-02    1.0
# 2015-01-05    1.0
# 2015-01-06    0.0
# 2015-01-07    1.0
# 2015-01-08    1.0
# 2015-01-09    1.0
# 2015-01-12    1.0
# 2015-01-13    1.0
# ...

# %%
TOOLS = 'save,pan,box_zoom,reset,wheel_zoom,hover'
q = figure(title="vol_shock_wo_close_shock", y_axis_type="linear", plot_height = 400,
           tools = TOOLS, plot_width = 800)
q.xaxis.axis_label = 'month'
q.yaxis.axis_label = 'vol_shock_wo_close_shock'
#p.circle(2010, infy.Close.min(), size = 10, color = 'red')

q.line(infy_vol_deriv.month, infy_vol_deriv.vol_shock_wo_close_shock,line_color="blue", line_width = 2)
q.select_one(HoverTool).tooltips = [
    ('month', '@x'),
    ('vol_shock_wo_close_shock', '@y'),
]
output_notebook() 
output_file("line_chart2.html", title="Line Chart")
show(q)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2428">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8a47b01b-d82e-4dbf-8908-e49a6df6516a"></div>
